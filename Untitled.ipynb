# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
true = np.load('results/Crossformer_AirQuality_il168_ol48_sl6_win2_fa10_dm256_nh4_el3_itr0/true.npy')
predict = np.load('results/Crossformer_AirQuality_il168_ol48_sl6_win2_fa10_dm256_nh4_el3_itr0/pred.npy')

# %%
index = 100
max_plot = 13
fig, axs = plt.subplots(max_plot, 1, figsize = (8,  max_plot * 2.3))
for i in range(max_plot):
    axs[i].plot(true[index, :, i], color = 'red')
    axs[i].plot(predict[index, :, i], color = 'blue')
